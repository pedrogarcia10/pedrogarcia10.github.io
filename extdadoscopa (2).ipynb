# %%
#Instalando o Selenium
# !pip install selenium

# Atualizando o Ubuntu para executar corretamento o apt-install
# !apt-get update

# Instalando o ChromeDrive e Trazendo ele para a Pasta Local
# !apt install chromium-chromedriver

# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.2 MB 7.3 MB/s
# ...
#      |████████████████████████████████| 384 kB 50.5 MB/s
# ...
#      |████████████████████████████████| 140 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# ...

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# %%
# Instanciando o Objeto ChromeOptions
options = webdriver.ChromeOptions()

# Passando algumas opções para esse ChromeOptions
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Criação do WebDriver do Chrome
navegador = webdriver.Chrome('chromedriver',options=options)

# %%
 links = ["https://www.oddsportal.com/soccer/world/world-cup-2022/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2018/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2014/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2010/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2006/results/",
  "https://www.oddsportal.com/soccer/europe/uefa-nations-league/results/",
  "https://www.oddsportal.com/soccer/europe/uefa-nations-league-2020-2021/results/",
  "https://www.oddsportal.com/soccer/europe/euro-2020/results/",
  "https://www.oddsportal.com/soccer/europe/euro-2008/results/",
  "https://www.oddsportal.com/soccer/europe/euro-2004/results/",
  "https://www.oddsportal.com/soccer/north-central-america/concacaf-nations-league/results/",
  "https://www.oddsportal.com/soccer/europe/uefa-nations-league-2018-2019/results/",
  "https://www.oddsportal.com/soccer/north-central-america/gold-cup/results/",
  "https://www.oddsportal.com/soccer/north-central-america/gold-cup-2019/results/",
  "https://www.oddsportal.com/soccer/north-central-america/gold-cup-2017/results/",
  "https://www.oddsportal.com/soccer/south-america/copa-america/results/",
  "https://www.oddsportal.com/soccer/south-america/copa-america-2019/results/",
  "https://www.oddsportal.com/soccer/south-america/copa-america-2016/results/",
  "https://www.oddsportal.com/soccer/south-america/copa-america-2015/results/",
  "https://www.oddsportal.com/soccer/world/fifa-confederations-cup/results/",
  "https://www.oddsportal.com/soccer/world/fifa-confederations-cup-2009/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2021/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2020/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2019/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2016/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2015/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2013/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2012/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2011/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2010/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2009/results/"]

# %%
linfos = list()
id_dias = list()
for j in range(0,len(links)):
  print(j)
  for i in range(1,20+1):
    navegador.get(links[j]+"#/page/"+str(i))

    div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/div[6]')
    html_content = div_mae.get_attribute('outerHTML')
    soup = BeautifulSoup(html_content,'html.parser')
    #print(soup.prettify())

    info = soup.find_all('tr',class_='odd deactivate')
    dia_fase = soup.find_all('tr',class_='center nob-border')

    linfo = [info[x].get_text(";")+";"+str(info[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]
    id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]

    print(links[j]+"#/page/"+str(i))
    print(len(linfo))
    #COLOCAR UMA CLAUSULAR ONDE SE LEN(LINFO) < 0, parar o loop
    linfos.extend(linfo)
    id_dias.extend(id_dia)
# Out:
# 0
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/1
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/2
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/3
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/4
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/5
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/6
# 29
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/7
# 30
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/8
# 29
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/9
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/10
# 31
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/11
# 30
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/12
# 29
# ...

# %%
linfos1 = linfos
id_dias1 = id_dias

# %%
links = ["https://www.oddsportal.com/soccer/world/friendly-international-2006/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2005/results/",
  "https://www.oddsportal.com/soccer/world/friendly-international-2004/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2021/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2019/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2017/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2015/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2013/results/",
  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2008/results/",
  "https://www.oddsportal.com/soccer/africa/african-nations-championship/results/",
  "https://www.oddsportal.com/soccer/africa/african-nations-championship-2016/results/",
  "https://www.oddsportal.com/soccer/africa/african-nations-championship-2014/results/",
  "https://www.oddsportal.com/soccer/asia/asian-cup/results/",
  "https://www.oddsportal.com/soccer/asia/asian-cup-2019/results/",
  "https://www.oddsportal.com/soccer/asia/asian-cup-2011/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2019/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2017/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2014/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2013/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2010/results/",
  "https://www.oddsportal.com/soccer/asia/gulf-cup-of-nations-2009/results/",
  "https://www.oddsportal.com/soccer/australia-oceania/ofc-nations-cup/results/",
  "https://www.oddsportal.com/soccer/australia-oceania/ofc-nations-cup-2012/results/",
  "https://www.oddsportal.com/soccer/australia-oceania/ofc-nations-cup-2008/results/"
  "https://www.oddsportal.com/soccer/europe/euro-2016/results/",
  "https://www.oddsportal.com/soccer/north-central-america/concacaf-nations-league-2019-2020/results/",

  "https://www.oddsportal.com/soccer/south-america/copa-america-2007/results/",

"https://www.oddsportal.com/soccer/world/fifa-confederations-cup-2013/results/",
"https://www.oddsportal.com/soccer/world/friendly-international-2017/results/",

  "https://www.oddsportal.com/soccer/world/friendly-international-2014/results/",
  "https://www.oddsportal.com/soccer/africa/african-nations-championship-2020/results/",
  "https://www.oddsportal.com/soccer/asia/asian-cup-2015/results/",  "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2010/results/",
    "https://www.oddsportal.com/soccer/europe/euro-2012/results/",
      "https://www.oddsportal.com/soccer/world/friendly-international-2018/results/"
        "https://www.oddsportal.com/soccer/africa/african-nations-championship-2011/results/",
 "https://www.oddsportal.com/soccer/africa/african-nations-championship-2018/results/",
   "https://www.oddsportal.com/soccer/africa/africa-cup-of-nations-2012/results/"]

# %%
linfos = list()
id_dias = list()
for j in range(0,len(links)):
  print(j)
  for i in range(1,20+1):
    navegador.get(links[j]+"#/page/"+str(i))

    div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/div[6]')
    html_content = div_mae.get_attribute('outerHTML')
    soup = BeautifulSoup(html_content,'html.parser')
    #print(soup.prettify())

    info = soup.find_all('tr',class_='odd deactivate')
    dia_fase = soup.find_all('tr',class_='center nob-border')

    linfo = [info[x].get_text(";")+";"+str(info[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]
    id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]

    print(links[j]+"#/page/"+str(i))
    print(len(linfo))

    linfos.extend(linfo)
    id_dias.extend(id_dia)
# Out:
# 0
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/1
# 30
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/2
# 30
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/3
# 30
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/4
# 30
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/5
# 27
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/6
# 29
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/7
# 0
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/8
# 0
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/9
# 0
# https://www.oddsportal.com/soccer/world/friendly-international-2006/results/#/page/10
# 0
# ...

# %%
linfos2 = linfos
id_dias2 = id_dias

# %%
links = [ "https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/",
         "https://www.oddsportal.com/soccer/world/friendly-international-2007/results/",
           "https://www.oddsportal.com/soccer/world/friendly-international-2008/results/",]

# %%
linfos = list()
id_dias = list()
for j in range(0,len(links)):
  print(j)
  for i in range(1,20+1):
    navegador.get(links[j]+"#/page/"+str(i))

    div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/div[6]')
    html_content = div_mae.get_attribute('outerHTML')
    soup = BeautifulSoup(html_content,'html.parser')
    #print(soup.prettify())

    info = soup.find_all('tr',class_='odd deactivate')
    dia_fase = soup.find_all('tr',class_='center nob-border')

    linfo = [info[x].get_text(";")+";"+str(info[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]
    id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]

    print(links[j]+"#/page/"+str(i))
    print(len(linfo))

    linfos.extend(linfo)
    id_dias.extend(id_dia)
# Out:
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/1
# 18
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/2
# 18
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/3
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/4
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/5
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/6
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/7
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/8
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/9
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/10
# 0
# https://www.oddsportal.com/soccer/south-america/copa-america-2011/results/#/page/11
# 0
# ...

# %%
linfos3 = linfos
id_dias3 = id_dias

# %%
linfos1.extend(linfos2)
id_dias1.extend(id_dias2)

# %%
linfos1.extend(linfos3)
id_dias1.extend(id_dias3)

# %%
len(linfos1), len(id_dias1)
# Out:
# (11740, 6573)

# %%
import pandas as pd
from google.colab import files
pd.DataFrame(linfos1).to_excel('df1.xlsx')
files.download('df1.xlsx')
pd.DataFrame(id_dias1).to_excel('df11.xlsx')
files.download('df11.xlsx')

# %%
#PRÓXIMOS JOGOS
links = ["https://www.oddsportal.com/soccer/world/world-cup-2022/"]
j = 0
navegador.get("https://www.oddsportal.com/soccer/world/world-cup-2022/")
div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/table')
html_content = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_content,'html.parser')
odd = soup.find_all('td',class_='odds-nowrp')
info = soup.find_all('td',class_='name table-participant')
b = soup.find_all('td',class_='center info-value')
id = soup.find_all('tr',class_='odd') #improviso
dia_fase = soup.find_all('tr',class_='center nob-border')
id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]
linfo = ["00:00" + ";" +info[x].get_text() + ";" + "-" + ";" + odd[3*x].get_text() + ";" + odd[3*x+1].get_text() + ";" + odd[3*x+2].get_text() + ";" + b[x].get_text() +";"+str(id[int(x/2)]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]

import pandas as pd
from google.colab import files
pd.DataFrame(linfo).to_excel('nextjogos1.xlsx')
files.download('nextjogos1.xlsx')
pd.DataFrame(id_dia).to_excel('nextjogos11.xlsx')
files.download('nextjogos11.xlsx')

# %%
import pandas as pd
from google.colab import files
pd.DataFrame(linfo).to_excel('nextjogos1.xlsx')
files.download('nextjogos1.xlsx')
pd.DataFrame(id_dia).to_excel('nextjogos11.xlsx')
files.download('nextjogos11.xlsx')

# %%
#estudo novo método
links = ["https://www.oddsportal.com/soccer/world/world-cup-2022/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2018/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2014/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2010/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2006/results/"]
j=1
i=1
navegador.get(links[j]+"#/page/"+str(i))

div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/div[6]')
html_content = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_content,'html.parser')

info = soup.find_all('tr',class_='odd deactivate')
dia_fase = soup.find_all('tr',class_='center nob-border')
info1 = soup.find_all('tr',class_=' deactivate')

linfo = [info[x].get_text(";")+";"+str(info[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]
linfo1 = [info1[x].get_text(";")+";"+str(info1[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info1))]
id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]
linfo.extend(linfo1)

# %%
links = ["https://www.oddsportal.com/soccer/world/world-cup-2022/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2018/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2014/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2010/results/",
  "https://www.oddsportal.com/soccer/world/world-cup-2006/results/"]

# %%
linfos = list()
id_dias = list()
for j in range(0,len(links)):
  print(j)
  for i in range(1,20+1):
    navegador.get(links[j]+"#/page/"+str(i))

    div_mae = navegador.find_element('xpath','/html/body/div[1]/div/div[2]/div[6]/div[1]/div/div[1]/div[2]/div[1]/div[6]')
    html_content = div_mae.get_attribute('outerHTML')
    soup = BeautifulSoup(html_content,'html.parser')

    info = soup.find_all('tr',class_='odd deactivate')
    dia_fase = soup.find_all('tr',class_='center nob-border')
    info1 = soup.find_all('tr',class_=' deactivate')

    linfo = [info[x].get_text(";")+";"+str(info[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info))]
    id_dia = [str(dia_fase[x]).split('span class=')[1][1:26]+";"+dia_fase[x].get_text(';')+";"+links[j] for x in range(0,len(dia_fase))]
    linfo1 = [info1[x].get_text(";")+";"+str(info1[x]).split("table-time ")[1].split(">")[0][0:25]+";"+links[j] for x in range(0,len(info1))]

    linfo.extend(linfo1)
    linfos.extend(linfo)
    id_dias.extend(id_dia)

    print(links[j]+"#/page/"+str(i))
# Out:
# 0
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/1
# 49
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/2
# 98
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/3
# 147
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/4
# 196
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/5
# 245
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/6
# 295
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/7
# 345
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/8
# 395
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/9
# 445
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/10
# 495
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/11
# 545
# https://www.oddsportal.com/soccer/world/world-cup-2022/results/#/page/12
# 595
# ...

# %%
import pandas as pd
from google.colab import files
pd.DataFrame(linfos).to_excel('worldcup1.xlsx')
files.download('worldcup1.xlsx')
pd.DataFrame(id_dias).to_excel('worldcup2.xlsx')
files.download('worldcup2.xlsx')
